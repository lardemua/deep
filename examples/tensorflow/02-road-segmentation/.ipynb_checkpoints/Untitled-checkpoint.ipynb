# %%
import tensorflow as tf

# %%
from PIL import Image

# %%
Image.open('/home/bml/datasets/cities-scapes/leftImg8bit/train/aachen/aachen_000049_000019_leftImg8bit.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2048x1024 at 0x7FB75EFF7250>
